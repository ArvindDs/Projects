# %% [markdown]
# <a href="https://colab.research.google.com/github/ArvindDs/Projects/blob/main/Project_14_scikit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import  drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Advertising Budget and Sales.csv")
df.head()
# Out:
#    Unnamed: 0  TV Ad Budget ($)  ...  Newspaper Ad Budget ($)  Sales ($)
# 0           1             230.1  ...                     69.2       22.1
# 1           2              44.5  ...                     45.1       10.4
# 2           3              17.2  ...                     69.3        9.3
# 3           4             151.5  ...                     58.5       18.5
# 4           5             180.8  ...                     58.4       12.9
#
# [5 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV Ad Budget ($)', 'Radio Ad Budget ($)',
#        'Newspaper Ad Budget ($)', 'Sales ($)'],
#       dtype='object')

# %%
df.shape

# %%
import matplotlib.pyplot as plt
import seaborn as sns
correlations = df.corr()
print(correlations)
# Out:
#                          Unnamed: 0  ...  Sales ($)
# Unnamed: 0                 1.000000  ...  -0.051616
# TV Ad Budget ($)           0.017715  ...   0.782224
# Radio Ad Budget ($)       -0.110680  ...   0.576223
# Newspaper Ad Budget ($)   -0.154944  ...   0.228299
# Sales ($)                 -0.051616  ...   1.000000
#
# [5 rows x 5 columns]

# %%
sns.heatmap(data = correlations,square = True, cmap = "bwr")
plt.yticks(rotation=0)
plt.xticks(rotation=90)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5]), <a list of 5 Text major ticklabel objects>)

# %%
df.isna().any()
# Out:
# Unnamed: 0                 False
# TV Ad Budget ($)           False
# Radio Ad Budget ($)        False
# Newspaper Ad Budget ($)    False
# Sales ($)                  False
# dtype: bool

# %%
import seaborn as sns
sns.boxplot(x=df['TV Ad Budget ($)'])

# %%
sns.boxplot(x=df['Radio Ad Budget ($)'])

# %%
sns.boxplot(x=df['Newspaper Ad Budget ($)'])

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
# store feature matrix in "X"
feature=['TV Ad Budget ($)','Radio Ad Budget ($)','Newspaper Ad Budget ($)']
X=df[feature]

# store response vector in "y"
y = df['Sales ($)']

# %%
X.shape
# Out:
# (200, 3)

# %%
y.shape
# Out:
# (200,)

# %%
df.shape
# Out:
# (200, 5)

# %%
# instantiate and fit
lm.fit(X,y)
# Out:
# LinearRegression()

# %%
# split  Data
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
X_train,X_test,Y_train,Y_test= train_test_split(X,y,test_size=0.2,random_state=1)

# %%
# instantiate and fit
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# Predict
Y_predict=lm.predict(X_test)

# %%
#RMSE
print(np.sqrt(metrics.mean_squared_error(Y_test,Y_predict)))
# Out:
# 1.4113417558581587
