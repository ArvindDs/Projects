# %% [markdown]
# <a href="https://colab.research.google.com/github/ArvindDs/Projects/blob/main/Project_4_operation_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Basic **operations**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
first_dis1=[2,4,6]
sec_dist2=[5,6,7]

# %%
import numpy as np

# %%
num_first_dis1= np.array([2,4,6])
num_sec_dist2=np.array([5,6,7])

# %%
total_dist=num_first_dis1+num_sec_dist2
total_dist
# Out:
# array([ 7, 10, 13])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#  cyclist first ad second trial access
cyclist_trial=first_dis1=np.array([[2,4,6],[5,6,7]])       # creating 2 D arrays of trials

# %%
first_trial=cyclist_trial[0]

# %%
first_trial
# Out:
# array([2, 4, 6])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
first_trial[1]
# Out:
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cyclist_trial.shape               # 2  rows 3 columns
# Out:
# (2, 3)

# %%
cyclist_trial[:,1:3]                    # : means consider all rows
# Out:
# array([[4, 6],
#        [6, 7]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for cyclist_data in cyclist_trial:
  print(cyclist_data)
# Out:
# [2 4 6]
# [5 6 7]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
student1= [12,18,34]
student2=[16,18,23]

# %%
test_score=np.array([[12,18,34],[16,18,23]])

# %%
passing_score=test_score>12

# %%
passing_score             # setting the passing score
# Out:
# array([[False,  True,  True],
#        [ True,  True,  True]])

# %%
# values of the passing score
test_score[passing_score]
# Out:
# array([18, 34, 16, 18, 23])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
square_root=np.sqrt([2,4,16])
square_root
# Out:
# array([1.41421356, 2.        , 4.        ])

# %%
from numpy import pi

# %%
np.cos(0)
# Out:
# 1.0

# %%
np.cos(pi/4)
# Out:
# 0.7071067811865476

# %%
np.sin(30)
# Out:
# -0.9880316240928618

# %%
np.exp([0,1,3])
# Out:
# array([ 1.        ,  2.71828183, 20.08553692])

# %%
np.floor([2,4,8])
# Out:
# array([2., 4., 8.])

# %%
np.floor([2.5,-0.9,6.8])
# Out:
# array([ 2., -1.,  6.])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a= np.array([[2,3,5,6,7,8],[5,4,7,2,9,0]])

# %%
np.ravel(a)                     # flattens the data
# Out:
# array([2, 3, 5, 6, 7, 8, 5, 4, 7, 2, 9, 0])

# %%
a.reshape(3,4)
# Out:
# array([[2, 3, 5, 6],
#        [7, 8, 5, 4],
#        [7, 2, 9, 0]])

# %%
a.resize(2,6)

# %%
a
# Out:
# array([[2, 3, 5, 6, 7, 8],
#        [5, 4, 7, 2, 9, 0]])

# %%
np.hsplit(a,2)
# Out:
# [array([[2, 3, 5],
#         [5, 4, 7]]), array([[6, 7, 8],
#         [2, 9, 0]])]

# %%
b=np.array([2,5,7,7,5,9])
c=np.array([4,5,8,9,34])

# %%
np.hstack((c,b))
# Out:
# array([ 4,  5,  8,  9, 34,  2,  5,  7,  7,  5,  9])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Import the necessary library
import numpy as np

# %%
#Manually add the Summer Olympics, London 2012 dataset as arrays
Country=np.array(['Great Britain','China','Russia','United States','Korea','Japan','Germany'])
Year=np.array([2012,2012,2012,2012,2012,2012,2012])
Gold=np.array([29,38,24,46,13,7,11])
Silver=np.array([17,28,25,28,8,14,11])
Bronze=np.array([19,22,32,29,7,17,14])

# %%
#### Find the country with maximum gold medals
maximum_gold_medals=Gold.argmax()
maximum_gold_medals
# Out:
# 3

# %%
country_maximum_gold= Country[maximum_gold_medals]

# %%
#Print the name of the country
print(country_maximum_gold)
# Out:
# United States

# %% [markdown]
# #### Find the countries with more than 20 gold medals

# %%
#Use Boolean indexing technique to find the required output
print(Country[Gold>20])
# Out:
# ['Great Britain' 'China' 'Russia' 'United States']

# %% [markdown]
# #### Evaluate the dataset and print the name of each country with its gold medals and total number of medals

# %%
#Use a for loop to create the required output
for i in range(len(Country)):
  gold_medal=Gold[i]
  Country_won=Country[i]
  total_medal= Gold[i]+Silver[i]+Bronze[i]
  print('{},gold medal{},Total Medal{}'.format(Country_won,gold_medal,total_medal))
# Out:
# Great Britain,gold medal29,Total Medal65
# China,gold medal38,Total Medal88
# Russia,gold medal24,Total Medal81
# United States,gold medal46,Total Medal103
# Korea,gold medal13,Total Medal28
# Japan,gold medal7,Total Medal38
# Germany,gold medal11,Total Medal36

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Countries=np.array(['Algeria','Angola','Argentina','Australia','Austria','Bahamas','Bangladesh',
           'Belarus','Belgium','Bhutan','Brazil','Bulgaria','Cambodia','Cameroon',
           'Chile','China','Colombia','Cyprus','Denmark','El Salvador','Estonia',
           'Ethiopia','Fiji','Finland','France','Georgia','Ghana','Grenada','Guinea',
           'Haiti','Honduras','Hungary','India','Indonesia','Ireland','Italy','Japan','Kenya', 
           'South Korea','Liberia','Malaysia','Mexico', 'Morocco','Nepal','New Zealand','Norway',
           'Pakistan', 'Peru','Qatar','Russia','Singapore','South Africa','Spain','Sweden','Switzerland',
           'Thailand', 'United Arab Emirates','United Kingdom','United States',
           'Uruguay','Venezuela','Vietnam','Zimbabwe'])

# %%
GDP_value=np.array([2255.225482,629.9553062,11601.63022,25306.82494,27266.40335,19466.99052,
                    588.3691778,2890.345675,24733.62696,1445.760002,4803.398244,2618.876037,
                    590.4521124,665.7982328,7122.938458,2639.54156,3362.4656,15378.16704,30860.12808,
                    2579.115607,6525.541272,229.6769525,2242.689259,27570.4852,23016.84778,1334.646773,
                    402.6953275,6047.200797,394.1156638,385.5793827,1414.072488,5745.981529,837.7464011,
                    1206.991065,27715.52837,18937.24998,39578.07441,478.2194906,16684.21278,
                    279.2204061,5345.213415,6288.25324,1908.304416,274.8728621,14646.42094,
                    40034.85063,672.1547506,3359.517402,36152.66676,3054.727742,33529.83052,
                    3825.093781,15428.32098,33630.24604,39170.41371,2699.123242,21058.43643,
                    28272.40661,37691.02733,9581.05659,5671.912202,757.4009286,347.7456605])

# %%
## Name of the country with  the highest GDP
highest_GDP= GDP_value.argmax()
highest_GDP
# Out:
# 45

# %%
Name_high_GDP=Countries[highest_GDP]
Name_high_GDP
# Out:
# 'Norway'

# %%
## Name of the country with  the highest GDP
lowest_GDP= GDP_value.argmin()

# %%
Name_lowest_GDP=Countries[lowest_GDP]
Name_lowest_GDP
# Out:
# 'Ethiopia'
