# %% [markdown]
# <a href="https://colab.research.google.com/github/ArvindDs/Projects/blob/main/Project_20_webscrap_11_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# import required libraries
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# url for web scraping
url= ('http://www.simplilearn.com')

# %%
# scrape the web page content
webpage=urlopen(url)

# %%
#create a soup object for parsing web page using html paraser
sl_soup=BeautifulSoup(webpage,'html.parser')

# %%
# close the  result object
webpage.close()

# %%
# View the content  of  the soup object
sl_soup.contents
# Out:
# ['html', <html dir="ltr" lang="en-US" xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <title>World's #1 Online Bootcamp &amp; Certification Course Provider | Simplilearn</title>
#  <link href="https://ssl.google-analytics.com/" rel="dns-prefetch"/>
#  <link href="https://stats.g.doubleclick.net/" rel="dns-prefetch">
#  <link href="https://www.google.com/" rel="dns-prefetch"/>
#  <link href="https://cdn.cookielaw.org/" rel="dns-prefetch"/>
#  <link href="https://js-agent.newrelic.com" rel="preconnect"/>
#  <script type="text/javascript">
#              var OneTrust = {
#                  geolocationResponse: {
#                      countryCode: 'NL'
#                  }
#              };
#          </script>
#  <!-- OneTrust Cookies Consent Notice start for simplilearn.com -->
# ...

# %%
# use prettify method to view well formatted output(html tags)
print(sl_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US" xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    World's #1 Online Bootcamp &amp; Certification Course Provider | Simplilearn
#   </title>
#   <link href="https://ssl.google-analytics.com/" rel="dns-prefetch"/>
#   <link href="https://stats.g.doubleclick.net/" rel="dns-prefetch">
#    <link href="https://www.google.com/" rel="dns-prefetch"/>
#    <link href="https://cdn.cookielaw.org/" rel="dns-prefetch"/>
#    <link href="https://js-agent.newrelic.com" rel="preconnect"/>
#    <script type="text/javascript">
#     var OneTrust = {
#                 geolocationResponse: {
#                     countryCode: 'NL'
#                 }
#             };
#    </script>
#    <!-- OneTrust Cookies Consent Notice start for simplilearn.com -->
# ...

# %%
# view the ktitle of the web page
sl_soup.title
# Out:
# <title>World's #1 Online Bootcamp &amp; Certification Course Provider | Simplilearn</title>

# %%
# find all the llinks present on the web page
for href in sl_soup.findAll('a',href=True):
  print(href['href'])
# Out:
# https://www.simplilearn.com/resources
# https://www.simplilearn.com/corporate-training
# https://www.simplilearn.com/become-our-trainer
# https://www.simplilearn.com/reseller-partner-program-for-training-courses?referrer=top-nav
# https://www.simplilearn.com
#
# #post-graduate-programs
#
# pgp-design-thinking-certification-training-course
# pgp-cloud-computing-certification-training-course
# pgp-digital-supply-chain-management-certification-training-course
# pgp-data-science-certification-bootcamp-program
# pgp-business-analysis-certification-training-course
# blockchain-certification-training-course
# pgp-digital-marketing-certification-program
# pgp-ai-machine-learning-certification-training-course
# pgp-devops-certification-training-course
# pgp-project-management-certification-training-course
# pgp-lean-six-sigma-certification-training-course
# pgp-full-stack-web-development-certification-training-course
# pgp-data-analytics-certification-training-course
# ...

# %%
# view all the  headers name
for  article in sl_soup.findAll('h2'):
  print(article.string)
# Out:
# Get Certified, Get Ahead with Our Programs
# An immersive learning experience
# None
# Employee and Team Training Solutions
# Learn free on the App

# %%
for  article_topic in sl_soup.findAll('h4'):
  print(article_topic.string)
# Out:
# Post Graduate Program in Design Thinking & Innovation
# Post Graduate Program in Cloud Computing
# Post Graduate Program in Digital Supply Chain Management
# Post Graduate Program in Data Science
# Post Graduate Program in Business Analysis
# Professional Certificate Program in Blockchain by IIT Kanpur
# Post Graduate Program in Digital Marketing
# Post Graduate Program in AI and Machine Learning
# Post Graduate Program in DevOps
# Post Graduate Program in Project Management
# Post Graduate Program in Lean Six Sigma
# Post Graduate Program in Full Stack Web Development
# Post Graduate Program in Data Analytics
# Post Graduate Program in Data Engineering
# Post Graduate Program in Cyber Security
# Post Graduate Program in Digital Transformation
# Professional Certificate Program in Cloud Computing
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# PMP® Certification Training
# None
# None
# None
# ...

# %%
"""
# #create  article object for finding the list
##the classs information is obtained from the web  page (view web page source)
# article_name=sl_soup.find(class_='knowledge-bank-div c_list')
#"""
# Out:
# "\n# #create  article object for finding the list\n##the classs information is obtained from the web  page (view web page source)\n# article_name=sl_soup.find(class_='knowledge-bank-div c_list')\n#"

# %%
url2='http://www.simplilearn.com/what-is-agile-project-management-article?source=frs_home'
webpage2=urlopen(url2)
sl_article=BeautifulSoup(webpage2,'html.parser')
test=sl_article.find(class_='desig_author empty-text')

# %%
# view the type of the article object
type(test)
# Out:
# bs4.element.Tag

# %%
# find first article name
test.findAll('p')
# Out:
# [<p>Since its inception, the <a href="https://www.simplilearn.com/tutorials/agile-scrum-tutorial/what-is-agile" rel="noopener" target="_blank" title="Agile methodology">Agile methodology</a> has come a long way to become a popular approach among a wide variety of organizations. For those unfamiliar with the term, Agile is a method of project management where projects are organized into epics then broken down into small manageable sections via chapters and sprints. While this method is most often associated with software development and <a href="https://www.simplilearn.com/tutorials/devops-tutorial/what-is-devops" rel="noopener" target="_blank" title="DevOps">DevOps</a>, it has a wide range of applications throughout the business. It’s a set of principles aligned with business goals that adequately handles the lack of predictability when it comes to <a href="https://www.simplilearn.com/tutorials/project-management-tutorial/what-is-project-management" rel="noopener" target="_blank" tit
# ...

# %%
#find first article name
first_next_p=test.p
first__next_p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-acaf4c5cc58c> in <module>()
#       1 #find first article name
#       2 first_next_p=test.p
# ----> 3 first__next_p
#
# NameError: name 'first__next_p' is not defined

# %%
#  find next siblings(next article name)
find_next_sibling=first_next_p.next_sibling.next_sibling
find_next_sibling
# Out:
# <h2 id="the_principles_of_project_management">The Principles of Project Management</h2>

# %%
#find  previous sibling(previous  article name)
find_next_sibling.previous_sibling
# Out:
# '\n'
